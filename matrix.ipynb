# %%
import torch
import numpy as np
import matplotlib.pyplot as plt

# %%
x = torch.tensor(4)
y = torch.tensor(3)

x*y
# Out:
# tensor(12)

# %%
x = torch.tensor([4, 5])
y = torch.tensor([1, 2])
x*y
# Out:
# tensor([ 4, 10])

# %%
x = torch.tensor([[1, 2],
                  [6, 7]])
y = torch.tensor([[4, 7],
                  [2, 3]])
x*y
# Out:
# tensor([[ 4, 14],
#         [12, 21]])

# %%
bs = lambda : torch.randint(0, 10, (2, 4))

n = bs()
m = bs()

# %%
n
# Out:
# tensor([[0, 2, 0, 4],
#         [9, 4, 7, 6]])

# %%
m
# Out:
# tensor([[1, 4, 1, 0],
#         [1, 8, 3, 5]])

# %%
n*m
# Out:
# tensor([[ 0,  8,  0,  0],
#         [ 9, 32, 21, 30]])

# %% [markdown]
# ![lol](image.png)

# %% [markdown]
# **Let's try it out with matrices of different dimensions**

# %%
n = torch.randint(0, 100, (4, 5)) # rows = 4, column = 5
m = torch.randint(0, 100, (4, 4)) # rows = 4, column = 4
plt.plot(n)
plt.plot(m)

# %% [markdown]
# ![alt text](image-1.png)

# %%
# for two matrices to multiply the number of columns in the first matrix must equal the number of rows in the second matrix

m1 = torch.randint(0, 100, (9, 5))
m2 = torch.randint(0, 100, (5, 6))


m3 =torch.matmul(m1, m2)

# %%
m1
# Out:
# tensor([[24, 82, 54,  5, 68],
#         [76,  9, 76, 94, 24],
#         [33, 17, 78,  5, 32],
#         [58, 40, 23, 45, 84],
#         [93, 73, 92, 58, 98],
#         [12, 31, 12, 74, 73],
#         [ 1, 29,  7, 46, 82],
#         [33, 82, 88, 47, 94],
#         [72, 37, 99, 82, 34]])

# %%
m2
# Out:
# tensor([[10,  6, 42, 21, 51, 68],
#         [73, 38, 18,  6, 31, 94],
#         [95, 82,  5, 86, 23,  9],
#         [85, 57, 86, 49, 26, 19],
#         [88, 90, 62,  4, 25, 68]])

# %%
m3
# Out:
# tensor([[17765, 14093,  7400,  6157,  6838, 14545],
#         [18739, 14548, 13306, 12888,  8947, 10116],
#         [12222, 10405,  4496,  7876,  4934,  6815],
#         [16902, 13879, 12349,  5977,  7997, 14478],
#         [28553, 23002, 16744, 13537, 13080, 21780],
#         [16237, 13022, 12012,  5388,  5598, 10208],
#         [13918, 11684,  9639,  3379,  4357,  9307],
#         [26943, 21669, 13172, 11432,  9821, 18029],
#         [22788, 17690, 13345, 14402, 10078, 13135]])
