# %% [markdown]
# # Exploring matplotlib.pyplot

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([2, 4, 5], list(map(lambda x: x+3, [2, 4, 5])), label='y = x + 3')
plt.title("Data")   
plt.xlabel("actual numbers")
plt.ylabel("numbers 3 more")
plt.legend()
plt.show()
